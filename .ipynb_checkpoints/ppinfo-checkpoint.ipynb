# %%
import pandas as pd 
import seaborn as sb
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('datasets/pinfo.csv').head(10)
datecolumn=ds.DateOfBirth

# %%
#replace / with - 
#convert string to date
#put 1992 in the section of stering 
# add new form to lis
#make the list column in our dataset
from datetime import datetime
now = datetime.now()
date_column=[]
for date in datecolumn:
    date_time_str=date.split('/')
    print(date_time_str)
    yer=str(date_time_str[2])
    print('yer is =',yer)

    ndate_time_str=date_time_str[0:2]
    print('withou yer',ndate_time_str)
    conca='19'+str(yer)
    print('adding 19 to the yer',conca)
#     fulldate=ndate_time_str.append('conca')
    print('the full date is',fulldate)
   
    for i in date_time_str:
        if len(i)==1:
            ff='0'+str(i)
            print(ff)

        
    
#     date_time_obj = datetime.strptime(date_time_str, '%d/%m/%y')
#     timestamp=date.replace('/','')
#     print(timestamp)
#     date_time = datetime.fromtimestamp(int(timestamp))
    
#     if int(len(date_time_str[0]))>2:
#         date_time_str[0]='0'.date_time_str[0]
#         print(date_time_str[0])
# Out:
# ['8', '5', '98']
# yer is = 98
# withou yer ['8', '5']
# adding 19 to the yer 1998
# the full date is None
# 08
# 05
# ['5', '15', '97']
# yer is = 97
# withou yer ['5', '15']
# adding 19 to the yer 1997
# the full date is None
# 05
# ['7', '1', '51']
# yer is = 51
# withou yer ['7', '1']
# adding 19 to the yer 1951
# the full date is None
# 07
# 01
# ['3', '29', '93']
# yer is = 93
# withou yer ['3', '29']
# adding 19 to the yer 1993
# the full date is None
# 03
# ['7', '1', '68']
# yer is = 68
# withou yer ['7', '1']
# adding 19 to the yer 1968
# the full date is None
# 07
# 01
# ['7', '1', '54']
# yer is = 54
# withou yer ['7', '1']
# adding 19 to the yer 1954
# the full date is None
# 07
# 01
# ['10', '7', '93']
# yer is = 93
# withou yer ['10', '7']
# adding 19 to the yer 1993
# the full date is None
# 07
# ['6', '5', '91']
# yer is = 91
# withou yer ['6', '5']
# adding 19 to the yer 1991
# the full date is None
# 06
# 05
# ['8', '28', '90']
# yer is = 90
# ...
